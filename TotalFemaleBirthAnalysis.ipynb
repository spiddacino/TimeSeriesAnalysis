# %%
#import necessary libraries
import pandas as pd
import kaggle

# %%
#call the kaggle authenticate API
kaggle.api.authenticate()

# %%
#download the dataset of Daily Total Female Births from kaggle using kaggle API
kaggle.api.dataset_download_files('kiranthakur007/california-female-birth-1959', path='data', unzip=True)

# %%
#read the csv file into a pandas dataframe
df = pd.read_csv('data\daily-total-female-births-CA_timeseries.csv', header=0, index_col=0, parse_dates=[0])

# %%
#view the first 5 rows of the dataframe
df.head()
# Out:
#             births
# date
# 1959-01-01      35
# 1959-01-02      32
# 1959-01-03      30
# 1959-01-04      31
# 1959-01-05      44

# %%
#convert the index to a column
# df.reset_index(inplace=True)

# %%
#get the columns of the dataframe
# df.columns

# %%
#check datatypes of the dataframe
# df['date'].dtype

# %%
#when working on time series projects, 
# if data came in as a column, convert it to a series instead of dataframe
# series = pd.Series(df['births'].values, index=df['date'])

# %%
#plot the births
df.plot()
# Out:
# <AxesSubplot: xlabel='date'>

# %%
#create a column date with the index
df['date'] = df.index

# %%
#view the first 5 rows of the dataframe
df.head()
# Out:
#             births       date
# date
# 1959-01-01      35 1959-01-01
# 1959-01-02      32 1959-01-02
# 1959-01-03      30 1959-01-03
# 1959-01-04      31 1959-01-04
# 1959-01-05      44 1959-01-05

# %%
#plot the births
df['births'].plot()
# Out:
# <AxesSubplot: xlabel='date'>

# %%
#plot the births for 1st to 10th january 1959
df['births']['1959-01-01':'1959-01-10'].plot()
# df['births']['1959-01'].plot()
# Out:
# <Axes: xlabel='date'>
